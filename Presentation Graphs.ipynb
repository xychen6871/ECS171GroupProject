# %%
from matplotlib.pyplot import bar

# %%
# Got example from https://matplotlib.org/stable/gallery/misc/table_demo.html#sphx-glr-gallery-misc-table-demo-py
# Testing MSEs only, with outliers(updated data)
simpLin = 0.0031034538994231665
multLin = 0.0026126372082117054
poly5Deg = 0.014125519364295569
nn = 0 # lowest value
bar(['Simple Linear', 'Multiple Linear', '5th Deg Polynomial', 'NN'], [simpLin, multLin, poly4Deg, nn], width=.2)
# Out:
# <BarContainer object of 4 artists>

# %%
from matplotlib.pyplot import bar
# Testing MSEs only, no outliers(updated data)

simpLinNoOutliers = 0.0176029338354731


multLinWithOutliers = 0.0168493824415378


poly5DegNoOutliers = 0.01022479

nnNoOutliers = 0

annWithOutliers = 0 # lowest value
bar(['Simple Linear', 'Multiple Linear', '5th Deg Polynomial', 'NN'], [simpLinNoOutliers, multLinWithOutliers, 
                                                                       poly5DegNoOutliers, nnNoOutliers], 
    width=.2)
# Out:
# <BarContainer object of 4 artists>
